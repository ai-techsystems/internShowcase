# %%
import numpy as np
import pandas as pd
from keras.layers import Dense,Dropout
from sklearn.model_selection import train_test_split
from keras.layers.normalization import BatchNormalization
from keras.models import Sequential
from keras.optimizers import RMSprop


def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean())

train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

print(train[['SalePrice']].mean())
y = np.log1p(train[['SalePrice']])
print(y.mean())
y = y.SalePrice
print(y.mean())

total = pd.concat((train.loc[:,'MSSubClass':'SaleCondition'],
                    test.loc[:,'MSSubClass':'SaleCondition']))
# Out:
# Using TensorFlow backend.
# SalePrice    180921.19589
# dtype: float64
# SalePrice    12.024057
# dtype: float64
# 12.024057394918371

# %%
total = pd.get_dummies(total)
total = total.fillna(total.mean())
x_train = np.array(total[:train.shape[0]])
x_test = np.array(total[test.shape[0]+1:])
X_tr, X_val, y_tr, y_val = train_test_split(x_train, y)

X_val.shape
model = Sequential()
BatchNormalization()
model.add(Dense(1024,input_dim=288,activation='relu'))
BatchNormalization()
Dropout(0.5)
model.add(Dense(256,input_dim=1024,activation='relu'))
BatchNormalization()
Dropout(0.8)
model.add(Dense(128))
BatchNormalization()
model.add(Dense(1))
model.compile( optimizer='adam',loss='mse',metrics=['mean_squared_error'])


model.fit(X_tr,y_tr,validation_data=(X_val,y_val),nb_epoch=35,batch_size=100,verbose=2)

model.summary()
# Out:
# C:\Users\biswa\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 1095 samples, validate on 365 samples
# Epoch 1/35
#  - 1s - loss: 1258954.4316 - mean_squared_error: 1258954.4316 - val_loss: 15062.0143 - val_mean_squared_error: 15062.0143
# Epoch 2/35
#  - 0s - loss: 32092.3332 - mean_squared_error: 32092.3332 - val_loss: 6605.8235 - val_mean_squared_error: 6605.8235
# Epoch 3/35
#  - 0s - loss: 8297.0104 - mean_squared_error: 8297.0104 - val_loss: 937.8716 - val_mean_squared_error: 937.8716
# Epoch 4/35
#  - 0s - loss: 2279.6598 - mean_squared_error: 2279.6598 - val_loss: 873.5913 - val_mean_squared_error: 873.5913
# Epoch 5/35
#  - 0s - loss: 1022.4265 - mean_squared_error: 1022.4265 - val_loss: 836.0769 - val_mean_squared_error: 836.0769
# Epoch 6/35
#  - 0s - loss: 1490.1321 - mean_squared_error: 1490.1321 - val_loss: 1546.9872 - val_mean_squared_error: 1546.9872
# Epoch 7/35
#  - 0s - loss: 568.8564 - mean_squared_error: 568.8564 - val_loss: 94.8993 - val_mean_squared_error: 94.8993
# Epoch 8/35
#  - 0s - loss: 105.5260 - mean_squared_error: 105.5260 - val_loss: 67.1373 - val_mean_squared_error: 67.1373
# Epoch 9/35
#  - 0s - loss: 159.4765 - mean_squared_error: 159.4765 - val_loss: 258.9405 - val_mean_squared_error: 258.9405
# Epoch 10/35
#  - 0s - loss: 491.8221 - mean_squared_error: 491.8221 - val_loss: 474.1948 - val_mean_squared_error: 474.1948
# Epoch 11/35
#  - 0s - loss: 680.8480 - mean_squared_error: 680.8480 - val_loss: 340.1279 - val_mean_squared_error: 340.1279
# Epoch 12/35
#  - 0s - loss: 1797.0830 - mean_squared_error: 1797.0830 - val_loss: 1333.6441 - val_mean_squared_error: 1333.6441
# Epoch 13/35
#  - 0s - loss: 997.2208 - mean_squared_error: 997.2208 - val_loss: 154.3028 - val_mean_squared_error: 154.3028
# Epoch 14/35
#  - 0s - loss: 824.9888 - mean_squared_error: 824.9888 - val_loss: 55.6758 - val_mean_squared_error: 55.6758
# Epoch 15/35
#  - 0s - loss: 754.2465 - mean_squared_error: 754.2465 - val_loss: 267.8275 - val_mean_squared_error: 267.8275
# Epoch 16/35
#  - 0s - loss: 325.2531 - mean_squared_error: 325.2531 - val_loss: 43.7069 - val_mean_squared_error: 43.7069
# Epoch 17/35
#  - 0s - loss: 254.2597 - mean_squared_error: 254.2597 - val_loss: 129.9677 - val_mean_squared_error: 129.9677
# Epoch 18/35
#  - 0s - loss: 583.5335 - mean_squared_error: 583.5335 - val_loss: 246.1382 - val_mean_squared_error: 246.1382
# Epoch 19/35
#  - 0s - loss: 260.1583 - mean_squared_error: 260.1583 - val_loss: 69.0867 - val_mean_squared_error: 69.0867
# Epoch 20/35
#  - 0s - loss: 124.0741 - mean_squared_error: 124.0741 - val_loss: 52.4276 - val_mean_squared_error: 52.4276
# Epoch 21/35
#  - 0s - loss: 66.3226 - mean_squared_error: 66.3226 - val_loss: 37.3374 - val_mean_squared_error: 37.3374
# Epoch 22/35
#  - 0s - loss: 36.1364 - mean_squared_error: 36.1364 - val_loss: 32.5201 - val_mean_squared_error: 32.5201
# Epoch 23/35
#  - 0s - loss: 28.0738 - mean_squared_error: 28.0738 - val_loss: 32.7412 - val_mean_squared_error: 32.7412
# Epoch 24/35
#  - 0s - loss: 29.1091 - mean_squared_error: 29.1091 - val_loss: 28.6080 - val_mean_squared_error: 28.6080
# Epoch 25/35
#  - 0s - loss: 29.4548 - mean_squared_error: 29.4548 - val_loss: 36.7071 - val_mean_squared_error: 36.7071
# Epoch 26/35
#  - 0s - loss: 32.3928 - mean_squared_error: 32.3928 - val_loss: 28.0486 - val_mean_squared_error: 28.0486
# Epoch 27/35
#  - 0s - loss: 39.9557 - mean_squared_error: 39.9557 - val_loss: 25.1450 - val_mean_squared_error: 25.1450
# Epoch 28/35
#  - 0s - loss: 26.4754 - mean_squared_error: 26.4754 - val_loss: 23.6916 - val_mean_squared_error: 23.6916
# Epoch 29/35
#  - 0s - loss: 29.9585 - mean_squared_error: 29.9585 - val_loss: 29.8323 - val_mean_squared_error: 29.8323
# Epoch 30/35
#  - 0s - loss: 36.2683 - mean_squared_error: 36.2683 - val_loss: 39.7619 - val_mean_squared_error: 39.7619
# Epoch 31/35
#  - 0s - loss: 25.3233 - mean_squared_error: 25.3233 - val_loss: 23.5173 - val_mean_squared_error: 23.5173
# Epoch 32/35
#  - 0s - loss: 31.9843 - mean_squared_error: 31.9843 - val_loss: 57.3632 - val_mean_squared_error: 57.3632
# Epoch 33/35
#  - 0s - loss: 112.0813 - mean_squared_error: 112.0813 - val_loss: 36.1796 - val_mean_squared_error: 36.1796
# Epoch 34/35
#  - 0s - loss: 57.9581 - mean_squared_error: 57.9581 - val_loss: 77.0236 - val_mean_squared_error: 77.0236
# Epoch 35/35
#  - 0s - loss: 115.2533 - mean_squared_error: 115.2533 - val_loss: 164.8998 - val_mean_squared_error: 164.8998
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              295936
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               262400
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 591,361
# Trainable params: 591,361
# Non-trainable params: 0
# _________________________________________________________________

# %%
preds = model.predict(np.array(X_val))
print(preds.shape)
print(X_val.shape)
print(y_val.shape)


print(y_val.mean())
print(preds.mean())
print(rmse(preds[0],y_val))

preds = model.predict(np.array(x_test))

sub = pd.read_csv("./sample_submission.csv")

sub.iloc[:,1] = np.array(model.predict(np.array(x_test)))
print(sub[['SalePrice']].mean())
sub['SalePrice'] = np.expm1(sub[['SalePrice']])
print(sub[['SalePrice']].mean())
sub.to_csv('kerassubmission1.csv', index=None)
print(sub.to_csv)
# Out:
# (365, 1)
# (365, 288)
# (365,)
# 12.012064627075883
# 22.530209
# 12.285732890744928
# SalePrice    22.6926
# dtype: float64
# SalePrice    5.240423e+40
# dtype: float64
# <bound method NDFrame.to_csv of         Id     SalePrice
# 0     1461  4.129985e+11
# 1     1462  1.072083e+12
# 2     1463  3.524218e+11
# 3     1464  3.074640e+11
# 4     1465  1.534390e+07
# 5     1466  7.116503e+09
# 6     1467  1.007098e+08
# 7     1468  3.885646e+09
# 8     1469  5.175399e+10
# 9     1470  6.295748e+08
# 10    1471  3.742636e+08
# 11    1472  3.743124e+06
# 12    1473  3.747371e+04
# 13    1474  1.419796e+06
# 14    1475  2.227355e+05
# 15    1476  5.136603e+10
# 16    1477  2.071822e+12
# 17    1478  7.875478e+09
# 18    1479  3.496841e+12
# 19    1480  2.536441e+09
# 20    1481  9.533870e+12
# 21    1482  1.952323e+08
# 22    1483  6.644747e+17
# 23    1484  1.470956e+06
# 24    1485  1.551336e+10
# 25    1486  1.328163e+09
# 26    1487  2.785026e+14
# 27    1488  6.523150e+09
# 28    1489  1.425790e+10
# 29    1490  1.073129e+10
# ...    ...           ...
# 1429  2890  5.923430e+08
# 1430  2891  1.118746e+09
# 1431  2892  8.110330e+09
# 1432  2893  5.511269e+08
# 1433  2894  9.712376e+07
# 1434  2895  1.909542e+07
# 1435  2896  1.300530e+05
# 1436  2897  5.822565e+21
# 1437  2898  2.161632e+09
# 1438  2899  2.292704e+09
# 1439  2900  1.297382e+10
# 1440  2901  5.496222e+40
# 1441  2902  4.913542e+07
# 1442  2903  4.278366e+11
# 1443  2904  6.279980e+09
# 1444  2905  7.609971e+27
# 1445  2906  1.048809e+08
# 1446  2907  3.678974e+03
# 1447  2908  2.993245e+09
# 1448  2909  1.218960e+12
# 1449  2910  7.104341e+05
# 1450  2911  9.363233e+04
# 1451  2912  1.427709e+11
# 1452  2913  6.493303e+04
# 1453  2914  2.846888e+06
# 1454  2915  9.065469e+06
# 1455  2916  6.494109e+05
# 1456  2917  1.300030e+17
# 1457  2918  1.037233e+11
# 1458  2919  3.309630e+11
#
# [1459 rows x 2 columns]>
