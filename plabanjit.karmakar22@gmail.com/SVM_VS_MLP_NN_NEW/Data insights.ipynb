# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns; sns.set(font_scale=1.2)

# %%
Titanic = pd.read_csv(r"C:\Users\user\Desktop\Titanic.csv")
Titanic.head()
# Out:
#    PassengerId                                               Name  SibSp  \
# 0            1                            Braund, Mr. Owen Harris      1
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2            3                             Heikkinen, Miss. Laina      0
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4            5                           Allen, Mr. William Henry      0
#
#    Parch            Ticket Pclass     Fare   Age     Sex Embarked  Survived
# 0      0         A/5 21171  Third   7.2500  22.0    Male        S         0
# 1      0          PC 17599  First  71.2833  38.0  Female        C         1
# 2      0  STON/O2. 3101282  Third   7.9250  26.0  Female        S         1
# 3      0            113803  First  53.1000  35.0  Female        S         1
# 4      0            373450  Third   8.0500  35.0    Male        S         0

# %%
sns.lmplot('Age','Survived',data=Titanic)

# %%
sns.lmplot('Age','Survived',data=Titanic,hue='Sex')

# %%
sns.lmplot('Age','Survived',data=Titanic,hue='Pclass')

# %%
sns.lmplot('Age','Survived',data=Titanic,hue='Embarked')
