# %% [markdown]
# Author - AITS Affiliation (www.ai-techsystems.com/)

# %%
# Importing the necessary Libraries
import numpy as np
import pandas as pd
import seaborn as sns
from numpy import median
import matplotlib.pyplot as plt
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:75% !important; }</style>"))

# Loading the Iris Data Set
df = pd.read_csv("Iris.csv")

# Checking the top 5 Rows of the Data Sets
df.head()
# Out:
# <style>.container { width:75% !important; }</style>
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Looking at the basic stats of the Data Sets 
print (df.describe())
print (df.info())
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
# Id               150 non-null int64
# SepalLengthCm    150 non-null float64
# SepalWidthCm     150 non-null float64
# PetalLengthCm    150 non-null float64
# ...

# %%
# Getting an idea about the outliers in the data by looking at the difference in mean and median
li = list(df.columns)
li.remove('Species')
for i in li:
    print ("The mean of", i, "is", df[i].mean())
    print ("The median of", i, "is", df[i].median())
    print ()
# Out:
# The mean of Id is 75.5
# The median of Id is 75.5
#
# The mean of SepalLengthCm is 5.843333333333335
# The median of SepalLengthCm is 5.8
#
# The mean of SepalWidthCm is 3.0540000000000007
# The median of SepalWidthCm is 3.0
#
# The mean of PetalLengthCm is 3.7586666666666693
# The median of PetalLengthCm is 4.35
#
# The mean of PetalWidthCm is 1.1986666666666672
# The median of PetalWidthCm is 1.3

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# setting the figure parameter
plt.rcParams['figure.figsize'] = [9,6]
sns.set(style = 'darkgrid')

# Counting the Species Present in the datasets
sns.countplot(x = df['Species'], data = df, palette = 'winter');
plt.title("Count of Species Present in the Data Set", fontsize = 16);

# %%
# This Scatterplot shows the relationship between Petal Width and Petal length for different Species
plt.rcParams['figure.figsize'] = [9,6]
Species = df[df["Species"] == 'Iris-setosa'].plot.scatter(x = 'PetalLengthCm', y = 'PetalWidthCm', color = 'darkcyan', label = 'Iris-Setosa')
df[df["Species"] == 'Iris-versicolor'].plot.scatter(x = 'PetalLengthCm', y = 'PetalWidthCm', color = 'mediumorchid', label = 'Iris-Versicolor', ax = Species)
df[df["Species"] == 'Iris-virginica'].plot.scatter(x = 'PetalLengthCm', y = 'PetalWidthCm', color = 'orange', label = 'Iris-Virginica', ax = Species);

Species.title.set_text("Relationship between Petal Width and Petal Length")

# %%
# This Scatterplot shows the relationship between Sepal Width and Sepal length for different Species
Species = df[df["Species"] == 'Iris-setosa'].plot.scatter(x = 'SepalLengthCm', y = 'SepalWidthCm', color = 'darkcyan', label = 'Iris-Setosa')
df[df["Species"] == 'Iris-versicolor'].plot.scatter(x = 'SepalLengthCm', y = 'SepalWidthCm', color = 'mediumorchid', label = 'Iris-Versicolor', ax = Species)
df[df["Species"] == 'Iris-virginica'].plot.scatter(x = 'SepalLengthCm', y = 'SepalWidthCm', color = 'orange', label = 'Iris-Virginica', ax = Species);

Species.title.set_text("Relationship between Sepal Width and Sepal Length")

# %% [markdown]
# Outliers

# %%
plt.rcParams['figure.figsize'] = [14,14]
fig, ax = plt.subplots(2,2)

# This box plot shows the outliers in the Petal length and the width 
sns.boxplot(y = df['PetalLengthCm'], x = df['Species'], data = df, ax = ax[0,0])
sns.boxplot(y = df['PetalWidthCm'], x = df['Species'], data = df, ax = ax[0,1])

# This box plot shows the outliers in the Sepal length and the width
sns.boxplot(y = df['SepalLengthCm'], x = df['Species'], data = df, ax = ax[1,0])
sns.boxplot(y = df['SepalWidthCm'], x = df['Species'], data = df, ax = ax[1,1]);

# %% [markdown]
# Distribution

# %%
# This histogram shows the distribution of various features of the data set
df.hist(edgecolor = 'white', linewidth = 1.1, color = 'darkcyan');
fig = plt.gcf()
fig.set_size_inches(12,12)
plt.show()

# %%
sns.jointplot(x = df['PetalLengthCm'], y = df['SepalLengthCm'], data = df, kind = 'kde');

# %%
sns.jointplot(x = df['PetalWidthCm'], y = df['SepalWidthCm'], data = df, kind ='kde');

# %% [markdown]
# Correlation

# %%
# The Correlation Matrix
corr = df.corr()
corr.style.background_gradient(cmap='winter')
# Out:
# <style  type="text/css" >
#     #T_6764b67a_bf51_11e9_b0ae_3860774fcb74row0_col0 {
#             background-color:  #00ff80;
#             color:  #000000;
#         }    #T_6764b67a_bf51_11e9_b0ae_3860774fcb74row0_col1 {
#             background-color:  #00bea0;
#             color:  #000000;
#         }    #T_6764b67a_bf51_11e9_b0ae_3860774fcb74row0_col2 {
#             background-color:  #0004fd;
#             color:  #f1f1f1;
#         }    #T_6764b67a_bf51_11e9_b0ae_3860774fcb74row0_col3 {
#             background-color:  #00ea8a;
#             color:  #000000;
#         }    #T_6764b67a_bf51_11e9_b0ae_3860774fcb74row0_col4 {
#             background-color:  #00ed88;
#             color:  #000000;
#         }    #T_6764b67a_bf51_11e9_b0ae_3860774fcb74row1_col0 {
#             background-color:  #00cc99;
#             color:  #000000;
#         }    #T_6764b67a_bf51_11e9_b0ae_3860774fcb74row1_col1 {
#             background-color:  #00ff80;
#             color:  #000000;
# ...

# %%
# The heatmap of the correlation of the features
plt.rcParams['figure.figsize'] = [12,8]
sns.heatmap(df.corr(), annot = True);

# %% [markdown]
# ### Preprocessing

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
# Making a dictionary to replace the Categorical values to Numerical Values
li_1 = list(df['Species'].unique())
li_2 = list(range(1,4))

species_dic = dict(zip(li_1,li_2))
print (species_dic)
# Out:
# {'Iris-setosa': 1, 'Iris-versicolor': 2, 'Iris-virginica': 3}

# %%
# Replacing the Categorical values to Numerical Values (Mapping)
df = df.replace({'Species':species_dic})

# %%
df['Species'].unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
Features = df[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]
target = df['Species']

# %%
# Splitting the Data Set into train and test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(Features, target, test_size = 0.30,random_state = 0)
print ("Train shape : ",X_train.shape)
print ("Test shape : ", X_test.shape)
# Out:
# Train shape :  (105, 4)
# Test shape :  (45, 4)

# %% [markdown]
# Plotting the Feature Importance Using the Boosted Gradient Descent

# %%
from xgboost import XGBClassifier
from xgboost import plot_importance

# Importing the performance metrics
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix

# %%
# Plotting the Feature Importances using the boosted gradient descent

# Training the Model
xgb_importance = XGBClassifier()
model_importance = xgb_importance.fit(X_train,y_train)

# Predicting using the trained XGB model
pred = model_importance.predict(X_test)

# Accuracy and f1_score of the XGB model
print ("Accuracy Score : ", accuracy_score(y_test, pred))
print ("f1_Score is    : ", f1_score(y_test, pred, average = 'weighted'))

# Plot feature importance
plot_importance(model_importance);
# Out:
# Accuracy Score :  0.9777777777777777
# f1_Score is    :  0.9779434092477569

# %%
model_importance.feature_importances_
# Out:
# array([0.02192196, 0.03536973, 0.7743051 , 0.16840316], dtype=float32)

# %% [markdown]
# ### Modelling

# %%
# Importing the Classifiers
from sklearn.cluster import MeanShift, estimate_bandwidth
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
import warnings; warnings.simplefilter('ignore')

# %% [markdown]
# Model 1-K Means Clustering

# %%
plt.rcParams['figure.figsize'] = [9,9]
f1_scores = []

# Training and Predicting the train and test set and claculating the f1_scores for a range of 1 to 20
for n in range (1,20):
    k_mean = KMeans(n_clusters = n, init = 'k-means++', max_iter = 300, random_state = 0)
    model_1 = k_mean.fit(X_train,y_train)
    pred_1 = model_1.predict(X_test)
    f1_scores.append(f1_score(y_test, pred_1, average = 'weighted'))

# Plotting the f1_scores
plt.xlabel("Number of Clusters")
plt.ylabel("f1_scores")
plt.title("f1 scores of different Clusters")
plt.plot(range(1,20),f1_scores);

# %%
# Selecting the best model
k_mean = KMeans(n_clusters = f1_scores.index(max(f1_scores))+1, init = 'k-means++', max_iter = 300, random_state = 0)
model_1 = k_mean.fit(X_train,y_train)

# Predicting with model_1
pred_1 = model_1.predict(X_test)

# Accuracy and f1_score of the model_1
f1_score_kmean = f1_score(y_test, pred_1, average = 'weighted')
print ("The Accuracy of the model_1 : ", accuracy_score(y_test, pred_1))
print ("The f1_score of the model_1 : ", f1_score_kmean)
# Out:
# The Accuracy of the model_1 :  0.7555555555555555
# The f1_score of the model_1 :  0.7155555555555556

# %% [markdown]
# Model 2 -Mean Shift Clustering

# %%
# Training the Model_2
bandwidth = estimate_bandwidth(X_train, quantile = 0.2, n_samples = 150)
model_2 = MeanShift(bandwidth = bandwidth, bin_seeding = True).fit(X_train, y_train)

# Predicting with model_2
pred_2 = model_2.predict(X_test)

# Accuracy and f1_score of the model_2
f1_score_shift = f1_score(y_test, pred_2, average = 'weighted')
print ("The Accuracy of the model_1 : ", accuracy_score(y_test, pred_2))
print ("The f1_score of the model_1 : ", f1_score_shift)
# Out:
# The Accuracy of the model_1 :  0.6222222222222222
# The f1_score of the model_1 :  0.6755555555555556

# %% [markdown]
# Model 3 - Agglomerative Clustering

# %%
f1_scores = []

# Training and Predicting the train and test set and claculating the f1_scores for a range of 1 to 20
for n in range (1,20):
    cluster = AgglomerativeClustering(n_clusters=n, affinity='euclidean', linkage='ward')
    model_3 = cluster.fit(X_train, y_train)
    pred_3 = model_3.fit_predict(X_test)
    f1_scores.append(f1_score(y_test, pred_3, average = 'weighted'))

# Plotting the f1_scores
plt.xlabel("Number of Clusters")
plt.ylabel("f1_scores")
plt.title("f1 scores of different Clusters")
plt.plot(range(1,20),f1_scores);

# %%
# Selecting the best model
cluster = AgglomerativeClustering(n_clusters = f1_scores.index(max(f1_scores))+1, affinity = 'euclidean', linkage = 'ward')
model_3 = cluster.fit(X_train, y_train)

# Predicting with model_3
pred_3 = model_3.fit_predict(X_test)

# Accuracy and f1_score of the model_3
f1_score_Agglo = f1_score(y_test, pred_3, average = 'weighted')
print ("The Accuracy of the model_1 : ", accuracy_score(y_test, pred_3))
print ("The f1_score of the model_1 : ", f1_score_Agglo)
# Out:
# The Accuracy of the model_1 :  0.6444444444444445
# The f1_score of the model_1 :  0.6910394265232974

# %% [markdown]
# Confusion Matrix of all the Clustering Algorithms

# %%
list_pred = [pred_1, pred_2, pred_3]
li_models = ['KMeans', 'Mean Shift', 'Agglomerative']

# The Confusion Matrices
for model, pred in zip(li_models, list_pred):
    print ("The Confusion Matrix of the ", model)
    print (pd.DataFrame(confusion_matrix(y_test, pred)))
    print ()
# Out:
# The Confusion Matrix of the  KMeans
#    0   1   2  3
# 0  0   0   0  0
# 1  0  16   0  0
# 2  0   0  18  0
# 3  7   0   4  0
#
# The Confusion Matrix of the  Mean Shift
#     0   1   2  3
# 0   0   0   0  0
# 1   0  16   0  0
# 2   6   0  12  0
# 3  11   0   0  0
#
# The Confusion Matrix of the  Agglomerative
#     0   1   2  3
# 0   0   0   0  0
# 1   0  16   0  0
# 2   5   0  13  0
# 3  11   0   0  0

# %% [markdown]
# Classification Report of all the Clustering Algorithms

# %%
# Classification Reports
for model, pred in zip(li_models, list_pred):
    print ("The Classification Report of the ", model)
    print (classification_report(y_test, pred))
    print ()
# Out:
# The Classification Report of the  KMeans
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      1.00      1.00        16
#            2       0.82      1.00      0.90        18
#            3       0.00      0.00      0.00        11
#
#     accuracy                           0.76        45
#    macro avg       0.45      0.50      0.47        45
# weighted avg       0.68      0.76      0.72        45
#
#
# The Classification Report of the  Mean Shift
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      1.00      1.00        16
#            2       1.00      0.67      0.80        18
#            3       0.00      0.00      0.00        11
#
#     accuracy                           0.62        45
#    macro avg       0.50      0.42      0.45        45
# weighted avg       0.76      0.62      0.68        45
#
# ...

# %%
# This Barplot shows the comparision between the f1 scores of the classifiers

li_2 = [f1_score_kmean, f1_score_shift, f1_score_Agglo]

sns.set(style = 'darkgrid')
plt.xlabel("Algorithms", fontsize = 18)
plt.ylabel("f1 Scores", fontsize = 18)
plt.title("F1 Scores of the Clustering Algorithms", fontsize = 18);
sns.barplot(x = li_models, y = li_2, palette = 'winter');

print ("The best Model is", li_models[li_2.index(max(li_2))], "with the f1_score of", max(li_2))
# Out:
# The best Model is KMeans with the f1_score of 0.7155555555555556
