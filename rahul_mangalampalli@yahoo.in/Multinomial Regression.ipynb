# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("train(cleaned).csv")

# %%
x =  df.corr()['SalePrice'] > 0

# %%
list1 =[]                   #Features with positive correlation are considered
for i in range(len(x)):
    if x.values[i] == True:
        list1.append(x.index[i])

# %%
list1 = list1[:-1]

# %%
y = df['SalePrice']
x = df[list1]

# %%
from sklearn.preprocessing import scale #package to scale data,this has to be done to avoid overfitting
x_ = scale(x)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x_,y,test_size = 0.2)

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_ = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_)
# Out:
# 1251059178.6494434

# %%
import matplotlib.pyplot as plt
plt.hist(y_test)
plt.hist(y_)
# Out:
# (array([ 1., 17., 44., 50., 54., 25., 23., 17.,  8.,  2.]),
#  array([  8055.18968153,  49093.19782474,  90131.20596796, 131169.21411118,
#         172207.22225439, 213245.23039761, 254283.23854082, 295321.24668404,
#         336359.25482726, 377397.26297047, 418435.27111369]),
#  <a list of 10 Patch objects>)

# %%
from sklearn.model_selection import cross_validate
scores = cross_validate(model, x_, y, cv=6,scoring = 'r2')

# %%
scores
# Out:
# {'fit_time': array([0.02802062, 0.02801371, 0.01996636, 0.02401757, 0.02397656,
#         0.02800298]),
#  'score_time': array([0.00397682, 0.        , 0.00400329, 0.        , 0.00398946,
#         0.        ]),
#  'test_score': array([0.86879201, 0.85426463, 0.77459088, 0.81250823, 0.75687422,
#         0.34342934])}

# %%
from sklearn.linear_model import Ridge
model_1 = Ridge(alpha=0.5)
model_1.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.5, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
y_1 = model_1.predict(x_test)

# %%
mean_squared_error(y_test,y_1)
# Out:
# 1247463102.8533864

# %%
plt.hist(y_test)
plt.hist(y_1)
# Out:
# (array([ 1., 17., 44., 50., 54., 25., 23., 17.,  8.,  2.]),
#  array([  8125.86832573,  49116.12333568,  90106.37834563, 131096.63335557,
#         172086.88836552, 213077.14337547, 254067.39838541, 295057.65339536,
#         336047.90840531, 377038.16341526, 418028.4184252 ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(y_test)
plt.hist(y_)
# Out:
# (array([ 1., 17., 44., 50., 54., 25., 23., 17.,  8.,  2.]),
#  array([  8055.18968153,  49093.19782474,  90131.20596796, 131169.21411118,
#         172207.22225439, 213245.23039761, 254283.23854082, 295321.24668404,
#         336359.25482726, 377397.26297047, 418435.27111369]),
#  <a list of 10 Patch objects>)

# %%
df3 = pd.read_csv('test.csv') #Data Cleaning For Test Sample

# %%
x_1= df3[list1]

# %%
x_1
# Out:
#       LotFrontage  LotArea Street LandContour LandSlope Neighborhood  \
# 0            80.0    11622   Pave         Lvl       Gtl        NAmes
# 1            81.0    14267   Pave         Lvl       Gtl        NAmes
# 2            74.0    13830   Pave         Lvl       Gtl      Gilbert
# 3            78.0     9978   Pave         Lvl       Gtl      Gilbert
# 4            43.0     5005   Pave         HLS       Gtl      StoneBr
# ...           ...      ...    ...         ...       ...          ...
# 1454         21.0     1936   Pave         Lvl       Gtl      MeadowV
# 1455         21.0     1894   Pave         Lvl       Gtl      MeadowV
# 1456        160.0    20000   Pave         Lvl       Gtl      Mitchel
# 1457         62.0    10441   Pave         Lvl       Gtl      Mitchel
# 1458         74.0     9627   Pave         Lvl       Mod      Mitchel
#
#      Condition1 Condition2 HouseStyle  OverallQual  ...  GarageArea  \
# 0         Feedr       Norm     1Story            5  ...       730.0
# 1          Norm       Norm     1Story            6  ...       312.0
# 2          Norm       Norm     2Story            5  ...       482.0
# 3          Norm       Norm     2Story            6  ...       470.0
# 4          Norm       Norm     1Story            8  ...       506.0
# ...         ...        ...        ...          ...  ...         ...
# 1454       Norm       Norm     2Story            4  ...         0.0
# 1455       Norm       Norm     2Story            4  ...       286.0
# 1456       Norm       Norm     1Story            5  ...       576.0
# 1457       Norm       Norm     SFoyer            5  ...         0.0
# 1458       Norm       Norm     2Story            7  ...       650.0
#
#       GarageQual GarageCond PavedDrive WoodDeckSF OpenPorchSF 3SsnPorch  \
# 0             TA         TA          Y        140           0         0
# 1             TA         TA          Y        393          36         0
# 2             TA         TA          Y        212          34         0
# 3             TA         TA          Y        360          36         0
# 4             TA         TA          Y          0          82         0
# ...          ...        ...        ...        ...         ...       ...
# 1454         NaN        NaN          Y          0           0         0
# 1455          TA         TA          Y          0          24         0
# 1456          TA         TA          Y        474           0         0
# 1457         NaN        NaN          Y         80          32         0
# 1458          TA         TA          Y        190          48         0
#
#       ScreenPorch MoSold SaleCondition
# 0             120      6        Normal
# 1               0      6        Normal
# 2               0      3        Normal
# 3               0      6        Normal
# 4             144      1        Normal
# ...           ...    ...           ...
# 1454            0      6        Normal
# 1455            0      4       Abnorml
# 1456            0      9       Abnorml
# 1457            0      7        Normal
# 1458            0     11        Normal
#
# [1459 rows x 49 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in x_1.columns:
    if x_1[i].dtypes == 'object':
        x_1[i].replace(np.nan,'Unlabelled',inplace = True)
        le.fit(x_1[i])
        x_1[i]= le.transform(x_1[i])
# Out:
# c:\users\amrut\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py:6788: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# c:\users\amrut\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
x_1['GarageYrBlt'].replace(np.nan,x_1['GarageYrBlt'].mean(),inplace =True)

# %%
x_1.isnull().sum()
# Out:
# LotFrontage      227
# LotArea            0
# Street             0
# LandContour        0
# LandSlope          0
# Neighborhood       0
# Condition1         0
# Condition2         0
# HouseStyle         0
# OverallQual        0
# YearBuilt          0
# YearRemodAdd       0
# RoofStyle          0
# RoofMatl           0
# Exterior1st        0
# Exterior2nd        0
# MasVnrType         0
# MasVnrArea        15
# ExterCond          0
# Foundation         0
# BsmtCond           0
# BsmtFinSF1         1
# BsmtFinType2       0
# BsmtUnfSF          1
# TotalBsmtSF        1
# CentralAir         0
# Electrical         0
# 1stFlrSF           0
# 2ndFlrSF           0
# GrLivArea          0
# BsmtFullBath       2
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# TotRmsAbvGrd       0
# Functional         0
# Fireplaces         0
# GarageYrBlt        0
# GarageCars         1
# GarageArea         1
# GarageQual         0
# GarageCond         0
# PavedDrive         0
# WoodDeckSF         0
# OpenPorchSF        0
# 3SsnPorch          0
# ScreenPorch        0
# MoSold             0
# SaleCondition      0
# dtype: int64

# %%
x_1['GarageCars'].replace(np.nan,x_1['GarageCars'].mean(),inplace =True)
x_1['GarageArea'].replace(np.nan,x_1['GarageArea'].mean(),inplace =True)
x_1['LotFrontage'].replace(np.nan,x_1['LotFrontage'].mean(),inplace =True)

# %%
x_1['MasVnrArea'].replace(np.nan,x_1['MasVnrArea'].mean(),inplace =True)

# %%
x_1['BsmtFinSF1'].replace(np.nan,x_1['BsmtFinSF1'].mean(),inplace =True)

# %%
x_1['BsmtUnfSF'].replace(np.nan,x_1['BsmtUnfSF'].mean(),inplace =True)

# %%
x_1['TotalBsmtSF'].replace(np.nan,x_1['BsmtUnfSF'].mean(),inplace =True)

# %%
x_1['BsmtFullBath'].replace(np.nan,x_1['BsmtFullBath'].mean(),inplace =True)

# %%
x_1.astype('int64')
# Out:
#       LotFrontage  LotArea  Street  LandContour  LandSlope  Neighborhood  \
# 0              80    11622       1            3          0            12
# 1              81    14267       1            3          0            12
# 2              74    13830       1            3          0             8
# 3              78     9978       1            3          0             8
# 4              43     5005       1            1          0            22
# ...           ...      ...     ...          ...        ...           ...
# 1454           21     1936       1            3          0            10
# 1455           21     1894       1            3          0            10
# 1456          160    20000       1            3          0            11
# 1457           62    10441       1            3          0            11
# 1458           74     9627       1            3          1            11
#
#       Condition1  Condition2  HouseStyle  OverallQual  ...  GarageArea  \
# 0              1           2           2            5  ...         730
# 1              2           2           2            6  ...         312
# 2              2           2           4            5  ...         482
# 3              2           2           4            6  ...         470
# 4              2           2           2            8  ...         506
# ...          ...         ...         ...          ...  ...         ...
# 1454           2           2           4            4  ...           0
# 1455           2           2           4            4  ...         286
# 1456           2           2           2            5  ...         576
# 1457           2           2           5            5  ...           0
# 1458           2           2           4            7  ...         650
#
#       GarageQual  GarageCond  PavedDrive  WoodDeckSF  OpenPorchSF  3SsnPorch  \
# 0              3           4           2         140            0          0
# 1              3           4           2         393           36          0
# 2              3           4           2         212           34          0
# 3              3           4           2         360           36          0
# 4              3           4           2           0           82          0
# ...          ...         ...         ...         ...          ...        ...
# 1454           4           5           2           0            0          0
# 1455           3           4           2           0           24          0
# 1456           3           4           2         474            0          0
# 1457           4           5           2          80           32          0
# 1458           3           4           2         190           48          0
#
#       ScreenPorch  MoSold  SaleCondition
# 0             120       6              4
# 1               0       6              4
# 2               0       3              4
# 3               0       6              4
# 4             144       1              4
# ...           ...     ...            ...
# 1454            0       6              4
# 1455            0       4              0
# 1456            0       9              0
# 1457            0       7              4
# 1458            0      11              4
#
# [1459 rows x 49 columns]

# %%
x_1 = scale(x_1)

# %%
y__ = model_1.predict(x_1)

# %%
x = pd.DataFrame(y__)
x.to_csv('sample_submission(Ridge).csv')

# %%
y__ = model.predict(x_1)

# %%
x = pd.DataFrame(y__)
x.to_csv('sample_submission(LinearReg).csv')
